# %%
'''
1. Python has several functions that are readily available for use.
2. These functions are called built-in functions.
'''

# %%
# abs()	Returns the absolute value of a number
x = abs(-10)    # Calculate distance from zero to given number without considering direction,
                # absolute value is never  negative
y= abs(4)
print(x)
print(y)

# %%
x = abs(4+7j)    # abs() function returns the magnitude part only.  root of ( 3 square + 4 square)
print(x)

# %%
#all()	Returns True if all items in an iterable object are true
mylist = [True, True, True]
mylist1= [False, False,False]
x = all(mylist1)
print(x)

# %%
a=10
b=5
a if a>b else b

# %%
#any()	Returns True if any item in an iterable object is true
mylist = [False, True, False]
x = any(mylist)
print(x)

# %%
#ascii()	Returns a readable version of an object. Replaces none-ascii characters with escape character
x = ascii("Welcome to SIMCA")
print(x)
print(ord('A'))

# %%
#bin()	Returns the binary version of a number
x = bin(10)
print(x)

# %%
#bool()	Returns the boolean value of the specified object
x = bool(1)
print(x)

# %%
#bytearray()	Returns an array of bytes
x = bytearray(6)
print(x)

# %%
#bytes()	Returns a bytes object
x = bytes(6)
print(x)

# %%
#callable()	Returns True if the specified object is callable, otherwise False
def t():     # callable
  a = 5
print("A")
x=5    # simple variable its callable
print(callable(t))
print(callable(print()))

# %%
#chr()	Returns a character from the specified Unicode code.
x = chr(67)
print(x)
print(ord('C'))
# Out:
# C
# 67

# %%
#compile()	Returns the specified source as an object, ready to be executed
x = compile('print(52)', 'test', 'eval')
exec(x)
# Out:
# 52

# %%
x=compile('str')
exec(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-f1acef475834> in <module>()
# ----> 1 x=compile('str')
#       2 exec(x)
#
# TypeError: compile() missing required argument 'filename' (pos 2)

# %%
#complex()	Returns a complex number
x = complex(3, 5)
print(x)
# Out:
# (3+5j)

# %%
#delattr()	Deletes the specified attribute (property or method) from the specified object
class Person:
  name = "ABC"
  age = 27
  country = "India"
  email="p@gmail.com"
delattr(Person, 'age')
p=Person()
print(p.country)
print(p.name)
print(p.email)
print(p.age)

# dictionay
# Out:
# India
# ABC
# p@gmail.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-666fb3c072e3> in <module>()
#      10 print(p.name)
#      11 print(p.email)
# ---> 12 print(p.age)
#      13
#      14 # dictionay
#
# AttributeError: 'Person' object has no attribute 'age'

# %%
#dict()	Returns a dictionary (Array)
x = dict(name = "Priya", age = 26, country = "India")
print(x)
dict1={'name1':"xyz"}
print(dict1)
# Out:
# {'name': 'Priya', 'age': 26, 'country': 'India'}
# {'name1': 'xyz'}

# %%
y={'A':1}
y
# Out:
# {'A': 1}

# %%
#dir()	Returns a list of the specified object's properties and methods
class Person:
  name = "Ashish"
  age = 24
  country = "India"

print(dir(Person))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'age', 'country', 'name']

# %%
#divmod()	Returns the quotient and the remainder when argument1 is divided by argument2
x = divmod(10, 2)
print(x)
# Out:
# (5, 0)

# %%
#enumerate()	Takes a collection (e.g. a tuple) and returns
              #it as an enumerate object
x = ('apple', 'banana', 'cherry')
y = enumerate(x)
print(tuple(y))
# Out:
# ((0, 'apple'), (1, 'banana'), (2, 'cherry'))

# %%
#eval()	Evaluates and executes an expression
x = 'print(55)'
eval(x)
x
# Out:
# 55
# 'print(55)'

# %%
#exec()	Executes the specified code (or object)
x = 'name = "Poonam"\nprint(name)'
exec(x)
exec('name = "Poonam"\nprint(name)')
eval('name = "Poonam"\nprint(name)')
# Out:
# Poonam
# Poonam
#   File "<string>", line 1
#     name = "Poonam"
#          ^
# SyntaxError: invalid syntax

# %%
import math
x=math.exp(3)    #e power n    2.712 ^ 3   n =1, 2, 3,4
print(x)
# Out:
# 20.085536923187668

# %%
#filter()	Use a filter function to exclude items in an iterable object
ages = [5, 12, 17, 18, 24, 32]

def myFunc(x):
  if x < 18:
    return False
  else:
    return True

adults = filter(myFunc, ages)

for x in adults:
  print(x)

# %%
#float()	Returns a floating point number
x = float(10)
print(x)

# %%
#format()	Formats a specified value
x = format(0.75, '%')
print(x)

# %%
#frozenset()	Returns a frozenset object
mylist = ['apple', 'banana', 'cherry']
x = frozenset(mylist)
print(x)

# %%
#getattr()	Returns the value of the specified attribute (property or method)
class Person:
  name = "ABC"
  age = 27
  country = "India"
  email="p@gmail.com"

x=getattr(Person, 'name')
print(x)

# %%
#globals()	Returns the current global symbol table as a dictionary
x = globals()
print(x)

# %%
#hasattr()	Returns True if the specified object has the specified attribute (property/method)
class Person:
  name = "ABC"
  age = 27
  country = "India"
  email="p@gmail.com"

x=hasattr(Person, 'name')
print(x)

# %%
#hex()	Converts a number into a hexadecimal value
x = hex(255)
print(x)

# %%
#id()	Returns the id of an object
x = ('apple', 'banana', 'cherry')
y = id(x)   #This value is the memory address of the object and will be different every time you run the program
print(y)

# %%
#input()	Allowing user input
print('Enter your name:')
x = input()
print('Hello, ' + x)

# %%
#int()	Returns an integer number
x = int(4.5)
print(x)

# %%
#isinstance()	Returns True if a specified object is an instance of a specified object
x = isinstance(5, float)
print(x)

# %%
#issubclass()	Returns True if a specified class is a subclass of a specified object
class myAge:
  age = 27

class myObj(myAge):
  name = "XYZ"
  age = myAge

x = issubclass(myObj, myAge)
print(x)

# %%
#iter()	Returns an iterator object
x = iter(["ABC", "PQR", "XYZ"])
print(next(x))
print(next(x))
print(next(x))
# Out:
# ABC
# PQR
# XYZ

# %%
#len()	Returns the length of an object
list = ["apple", "banana", "cherry"]
x = len(list)
print(x)

# %%
#list()	Returns a list
list = ["apple", "banana", "cherry"]
print(list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#locals()	Returns an updated dictionary of the current local symbol table
x = locals()
print(x)
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '# abs()\tReturns the absolute value of a number\nx = abs(-7.25)\nprint(x)', '# abs()\tReturns the absolute value of a number\nx = abs(-7.25)\ny=abs(7.25)\nprint(x)\nprint(y)', 'x = abs(4+7j)\nprint(x)', '#all()\tReturns True if all items in an iterable object are true\nmylist = [True, True, True]\nx = all(mylist)', '#all()\tReturns True if all items in an iterable object are true\nmylist = [True, True, True]\nx = all(mylist)', '#all()\tReturns True if all items in an iterable object are true\nmylist = [True, True, True]\nx = all(mylist)\nprint(x)', '#all()\tReturns True if all items in an iterable object are true\nmylist = [True, False, True]\nx = all(mylist)\nprint(x)', '#all()\tReturns True if all items in an iterab
# ...

# %%
#max()	Returns the largest item in an iterable
x = max(5, 100)
print(x)
# Out:
# 100

# %%
#memoryview()	Returns a memory view object
x = memoryview(b"Hi")

print(x)

#return the Unicode of the first character
print(x[0])

#return the Unicode of the second character
print(x[1])
# Out:
# ...
# 72
# 105

# %%
#min()	Returns the smallest item in an iterable
x = min(5, 100)
print(x)
# Out:
# 5

# %%
#next()	Returns the next item in an iterable
mylist = iter(["apple", "banana", "cherry"])
x = next(mylist)
print(x)
x = next(mylist)
print(x)
x = next(mylist)
print(x)
# Out:
# apple
# banana
# cherry

# %%
#object()	Returns a new object
x = object()
print(x)

# %%
#oct()	Converts a number into an octal
x = oct(12)
print(x)
# Out:
# 0o14

# %%
#ord()	Convert an integer representing the Unicode of the specified character
x = ord("a")
print(x)
# Out:
# 97

# %%
#pow()	Returns the value of x to the power of y
x = pow(2, 3)  # 2^3=8
print(x)
# Out:
# 8

# %%
#range()	Returns a sequence of numbers, starting from 0 and increments by 1 (by default)
x = range(6)
for n in x:
  print(n)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
#reversed()	Returns a reversed iterator
a = ["a", "b", "c", "d"]
ra = reversed(a)
for x in ra:
  print(x)
# Out:
# d
# c
# b
# a

# %%
#round()	Rounds a numbers
x = round(5.76543, 2)
print(x)
# Out:
# 5.77

# %%
#set()	Returns a new set object
x = set(('apple', 'banana', 'cherry'))
print(x)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
#setattr()	Sets an attribute (property/method) of an object
class Person:
  name = "ABC"
  age = 27
  country = "India"

setattr(Person, 'age', 42)
P=Person()
print(P.age)
# Out:
# 42

# %%
#slice()	Returns a slice object
a = ("a", "b", "c", "d", "e", "f", "g", "h")
x = slice(3)
print(a[x])
# Out:
# ('a', 'b', 'c')

# %%
#sorted()	Returns a sorted list
a = ("b", "g", "a", "d", "f", "c", "h", "e")
x = sorted(a)
print(x)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
#str()	Returns a string object
x = str(3.5)
print(x)
# Out:
# 3.5

# %%
#sum()	Sums the items of an iterator
a = (1, 2, 3, 4, 5)
x = sum(a)
print(x)
# Out:
# 15

# %%
#super()	Returns an object that represents the parent class
class Parent:
  def __init__(self, txt):
    self.message = txt

  def printmessage(self):
    print(self.message)

class Child(Parent):
  def __init__(self, txt):
    super().__init__(txt)

x = Child("Hello, and welcome!")

x.printmessage()
# Out:
# Hello, and welcome!

# %%
#tuple()	Returns a tuple
x = tuple(('a', 'b', 'c'))
print(x)
# Out:
# ('a', 'b', 'c')

# %%
#type()	Returns the type of an object
a = ('apple', 'banana', 'cherry')
b = "Hello World"
c = 33

x = type(a)
y = type(b)
z = type(c)
print(x,y,z)
# Out:
# <class 'tuple'> <class 'str'> <class 'int'>

# %%
#vars()	Returns the __dict__ property of an object
class Person:
  name = "ABC"
  age = 26
  country = "India"

x = vars(Person)
print(x)
# Out:
# {'__module__': '__main__', 'name': 'ABC', 'age': 26, 'country': 'India', '__dict__': <attribute '__dict__' of 'Person' objects>, '__weakref__': <attribute '__weakref__' of 'Person' objects>, '__doc__': None}

# %%
#zip()	Returns an iterator, from two or more iterators
a = ("A", "B", "C")
b = ("D", "E", "F")
x = zip(a, b)
print(tuple(x))
# Out:
# (('A', 'D'), ('B', 'E'), ('C', 'F'))
