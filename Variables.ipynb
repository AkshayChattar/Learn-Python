# %% [markdown]
# # **Variables**

# %%
print ("Hello Welcome to Python Programming")
2*10

# %%
print(list("Hello World"))
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
mylist=list([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# There is no need of declaring variables before using it.
# Python is dynamically typed therefore no need to declare variables before use.
# Declaration happens automatically when you assign a value to a variable
a=10.5
print(type(a))
                      # Check data type of variable
print("Value of a=", a)                # , is works as concatenation operator
# Out:
# <class 'float'>
# Value of a= 10.5

# %%
# Usage of print()
print("Hello")
str="Welcome to Python Programming"
print(str)
# Out:
# Hello
# Welcome to Python Programming

# %%
x=True
type(x)
# Out:
# bool

# %%
# No datatype is used as prefix like other languages
num1=10     # integer value
num2=10.5   # float
Name='Poonam' # String
exp=None      # None / Null Value

# %%
# Variables can change type simply by assigning them a new value of diffrent type
x=1      # interpreter will identify as integer
x="Poonam"   # String
print(type(x))

# %%
#Python allows you to assign a single value to multiple variables in a single line
a=b=c=10   # All three variables hold the same value
print("Value of a=",a,"Value of b=",b,"Value of c=",c)
print(a+b)
# Out:
# Value of a= 10 Value of b= 10 Value of c= 10
# 20

# %%
# It also allows to assign a multiple objects to multiple variables in a single line

a=b=c=10,10.5,"Poonam"
print(a,b,c)
print(type(a))
print(type(b))
print(type(c))
print(a+b)
print(a)
# Out:
# (10, 10.5, 'Poonam') (10, 10.5, 'Poonam') (10, 10.5, 'Poonam')
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# (10, 10.5, 'Poonam', 10, 10.5, 'Poonam')
# (10, 10.5, 'Poonam')

# %%
type(a)

# %%
a=10,10.5
b=10
b=10.5
print(a)
type(a)

# %%
a=1=2   # can't assign to literal
print(a)
# Out:
#   File "<ipython-input-21-00beb326607a>", line 1
#     a=1=2   # can't assign to literal
#       ^
# SyntaxError: cannot assign to literal

# %%
# Conditions for constructing variable names
#Variables can be named alphanumerically
Age=10
Age1=20
age=20

# %%
2age=20   # we can not start with numerical
print(2age)
# Out:
#   File "<ipython-input-12-c60b6769f5fe>", line 1
#     2age=20   # we can not start with numerical
#     ^
# SyntaxError: invalid decimal literal

# %%
emp_1=201
emp_2=301
#emp@1=201  # wrong declaration
print(emp_1)
print(emp_2)
# Out:
# 201
# 301

# %%
_age=20              # It will not through error but it is not not a good practice
age_=40
print(_age)
print(age_)
# Out:
# 20
# 40

# %%
# Case sensitive, Rohit, rohit,ROHIT all are different variables
Rohit=10
print(rohit)

# %%
Data types

premitive datatypes
numbers
    integer  int  1,2, -1
    float    decimal numbers 2.0, 2.50,2.51
  boolean(0 and 1)
      True
      False
  string
  complex number: a+ib

# %%
print() : to display output
 1) you can directly pass string
 2)you can use variable as a parameter

# %%
print("Welcome to python programming")

# %%
str="Hello"
print(str)

# %%
a=10
b=20
c=a+b
print("Addition of a and b is:",c)
print("Addition of {}".format(a)+" and {}".format(b),"is: {}".format(c))

# %%
print("xyz")
print("x")
# Out:
# xyz
# x

# %%
sum=0
for i in range(0,50,2):
  sum=sum+i
print(sum)

# %%
# type(): to check  data type of variable

a=10
b=10.5
c="xyz"
d=True
e=2+ 4j
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))

# %%
#input(): Accepts input from user
str=input("Enter String ")
print(str)
type(str)

# %%
a=input("Enter Number:  ")
b=input("Enter Number: ")
c=int(a)+float(b)
print(c)

# %%
a=int(input("Enter Number:  "))
b=int(input("Enter Number: "))
print(a+b)

# %%
int(), float(), ord(), str(),tupel(),list(),set()

# %%
str="Neha"
c=int(str)
print(c)

# %%
name="A"
print(ord(name))
# Out:
# 65

# %%
s="poonam"
L=list(s)
print(L)
type(L)

# %%
s="poonam"
T=tuple(s)
print(T)
type(T)

# %%
s="poonam"
T=set(s)
print(T)
type(T)

# %%
b={"A":1,"B":2,"C":3,"D":4,"E":5}
type(b)

# %%
Arithmetic:  +, -, *, /,//,%,**
Comparision :<, >,<=,>=,==,!=
Logical : and, or, not
Assignment: a+=b, -=,*=,/=,//=,%=,**=
Membership: in , not in
Identity : is , is not
Bitwise: &, !, ~, ^,>>,<<
